# %%
import pandas as pd

# %%
df = pd.DataFrame([[1, 'a'],[2,'b'],[3,'c'],[4,'d']], columns=['a','b'])

# %%
df
# Out:
#    a  b
# 0  1  a
# 1  2  b
# 2  3  c
# 3  4  d

# %% [markdown]
# How to iterate over rows in a DataFrame in Pandas?

# %%
print("Method 1:", end = " ")
for index in range(len(df)):
    print(df["a"][index], end = " ")
# Out:
# Method 1: 1 2 3 4

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# How do I select rows from a DataFrame based on column values?

# %%
## Method 1: Filter on one column
print(df[df.a>2])

## Method 2: Filter on multiple columns
print(df[df.a>1][df.a== "B"])

## Method 3: Filter from list
print(df[df.b.isin(["A", "B"])])

## Method 4: using df.query()
print(df.query('a> 2'))
# Out:
#    a  b
# 2  3  c
# 3  4  d
# Empty DataFrame
# Columns: [a, b]
# Index: []
# Empty DataFrame
# Columns: [a, b]
# Index: []
#    a  b
# 2  3  c
# 3  4  d
# C:\Users\qw\AppData\Local\Temp\ipykernel_2300\521059102.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(df[df.a>1][df.a== "B"])

# %%
import numpy as np

# %%
s = pd.Series([1,2,3,4,5,np.nan,9])

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# 6    9.0
# dtype: float64

# %%
dates =pd.date_range('20200301', periods=10)

# %%
dates
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(10,4), index=dates, columns=['a','b','b','c'])

# %%
df
# Out:
#                    a         b         b         c
# 2020-03-01  0.034071  1.251536 -0.651578 -1.515283
# 2020-03-02 -0.128727  0.714053  0.394319  0.599873
# 2020-03-03 -0.331676  0.241077  0.158310 -0.987240
# 2020-03-04  0.191855  2.088161  1.128162 -0.730286
# 2020-03-05 -0.359170 -0.480804  0.371833  0.850826
# 2020-03-06  1.263883 -0.964344  0.791697  0.886462
# 2020-03-07  0.788292  0.650068 -0.638517  2.193467
# 2020-03-08  0.288075  0.341095 -0.023354 -0.984920
# 2020-03-09 -0.193730  0.063532  0.661940  0.853488
# 2020-03-10  0.297866 -0.532534 -1.090245  0.662595

# %%
df = pd.DataFrame({'a': [1,2,3,4],
                  'b':pd.Timestamp('20200301'),
                  'c':pd.Series(1, index=list(range(4)),dtype='float32'),
                'd':np.array([5]*4, dtype='int32'),
                 'e':pd.Categorical(['true','false','true','false']),
                    'f':'edureka'})

# %%
df
# Out:
#    a          b    c  d      e        f
# 0  1 2020-03-01  1.0  5   true  edureka
# 1  2 2020-03-01  1.0  5  false  edureka
# 2  3 2020-03-01  1.0  5   true  edureka
# 3  4 2020-03-01  1.0  5  false  edureka

# %%
df.dtypes
# Out:
# a             int64
# b    datetime64[ns]
# c           float32
# d             int32
# e          category
# f            object
# dtype: object

# %%
df.type.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2300\1668150004.py in <module>
# ----> 1 df.type.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
df.info

# %%
df.describe()

# %%
import tabula

# %%
df = tabula.read_pdf('street.pdf',pages=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\tabula\io.py in _run(java_options, options, path, encoding)
#      87     try:
# ---> 88         result = subprocess.run(
#      89             args,
#
# ~\Anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ...

# %%
import pandas as pd
df= pd.read_csv('street.csv')

# %%
df.head()
# Out:
#                  2015 Street Tree Census - Tree Data  \
# 0  Street tree data from the TreesCount! 2015 Str...
# 1                             partner organizations.
# 2  indicating status of data collection and data ...
# 3                                                NaN
# 4                                              Field
#
#                                           Unnamed: 1         Unnamed: 2  \
# 0                                                NaN                NaN
# 1  Tree data collected includes tree species, dia...                NaN
# 2                                                NaN                NaN
# 3                                   Field Name as it                NaN
# 4                                         appears in  Data Field Source
#
#   Unnamed: 3   Unnamed: 4                                Unnamed: 5  \
# 0        NaN          NaN                                       NaN
# 1        NaN          NaN  Accompanying blockface data is available
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   2015 Street Tree Census - Tree Data  82 non-null     object
#  1   Unnamed: 1                           53 non-null     object
#  2   Unnamed: 2                           95 non-null     object
#  3   Unnamed: 3                           111 non-null    object
#  4   Unnamed: 4                           66 non-null     object
#  5   Unnamed: 5                           8 non-null      object
#  6   Unnamed: 6                           144 non-null    object
#  7   Unnamed: 7                           19 non-null     object
# dtypes: object(8)
# memory usage: 17.4+ KB

# %%
df.describe()
# Out:
#        2015 Street Tree Census - Tree Data        Unnamed: 1  \
# count                                   82                53
# unique                                  70                44
# top                                  Field  Field Name as it
# freq                                     4                 4
#
#                         Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# count                           95        111           66
# unique                          12         40           61
# top     User collected data in the       Text  Description
# freq                            20         25            4
#
#                                       Unnamed: 5  \
# count                                          8
# unique                                         8
# top     Accompanying blockface data is available
# freq                                           1
#
#                                                Unnamed: 6 Unnamed: 7
# ...

# %%
data=pd.read_csv('street_tree.csv')

# %%
data.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common  ...  boro_ct  \
# 0                         Acer rubrum        red maple  ...  4073900
# 1                   Quercus palustris          pin oak  ...  4097300
# 2  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 3  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 4                     Tilia americana  American linden  ...  3016500
#
#       state   latitude  longitude         x_sp         y_sp council district  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683788 entries, 0 to 683787
# Data columns (total 45 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   tree_id           683788 non-null  int64
#  1   block_id          683788 non-null  int64
#  2   created_at        683788 non-null  object
#  3   tree_dbh          683788 non-null  int64
#  4   stump_diam        683788 non-null  int64
#  5   curb_loc          683788 non-null  object
#  6   status            683788 non-null  object
#  7   health            652172 non-null  object
#  8   spc_latin         652169 non-null  object
#  9   spc_common        652169 non-null  object
#  10  steward           652173 non-null  object
#  11  guards            652172 non-null  object
#  12  sidewalk          652172 non-null  object
#  13  user_type         683788 non-null  object
#  14  problems          652124 non-null  object
#  15  root_stone        683788 non-null  object
# ...

# %%
data.describe()
# Out:
#              tree_id       block_id       tree_dbh     stump_diam  \
# count  683788.000000  683788.000000  683788.000000  683788.000000
# mean   365205.011085  313793.096236      11.279787       0.432463
# std    208122.092902  114839.024312       8.723042       3.290241
# min         3.000000  100002.000000       0.000000       0.000000
# 25%    186582.750000  221556.000000       4.000000       0.000000
# 50%    366214.500000  319967.000000       9.000000       0.000000
# 75%    546170.250000  404624.000000      16.000000       0.000000
# max    722694.000000  999999.000000     450.000000     140.000000
#
#             postcode  community board       borocode       cncldist  \
# count  683788.000000    683788.000000  683788.000000  683788.000000
# mean    10916.246044       343.505404       3.358500      29.943181
# std       651.553364       115.740601       1.166746      14.328531
# min        83.000000       101.000000       1.000000       1.000000
# ...

# %%
data.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
data_subset=data[['tree_id','tree_dbh', 'stump_diam',
       'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
       'guards', 'sidewalk', 'problems', 'root_stone',
       'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
       'brch_light', 'brch_shoe', 'brch_other']]
data_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin           spc_common steward  \
# 0                              Acer rubrum            red maple    None
# 1                        Quercus palustris              pin oak    None
# ...

# %%
data_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# spc_common    31619
# steward       31615
# guards        31616
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
data_subset[data_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
data_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
data_subset.dtypes
# Out:
# tree_id        int64
# tree_dbh       int64
# stump_diam     int64
# curb_loc      object
# status        object
# health        object
# spc_latin     object
# spc_common    object
# steward       object
# guards        object
# sidewalk      object
# problems      object
# root_stone    object
# root_grate    object
# root_other    object
# trunk_wire    object
# trnk_light    object
# trnk_other    object
# brch_light    object
# brch_shoe     object
# brch_other    object
# dtype: object

# %%
data_subset.hist(bins=60, figsize=(20,10));

# %%
data_subset[data_subset['tree_dbh']>50]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675265   179496        52           0  OffsetFromCurb  Alive   Good
# 677954   166796        54           0          OnCurb  Alive   Good
# 679894   169501        51           0          OnCurb  Alive   Good
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin       spc_common steward guards  \
# ...

# %%
big_trees=data_subset[['tree_id','tree_dbh']].plot(kind='scatter',x='tree_id',y='tree_dbh', figsize=(20,10));

# %%
data_subset['spc_latin'].value_counts()
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
data_subset['tree_id']
# Out:
# 0         180683
# 1         200540
# 2         204026
# 3         204337
# 4         189565
#            ...
# 683783    155433
# 683784    183795
# 683785    166161
# 683786    184028
# 683787    200607
# Name: tree_id, Length: 683788, dtype: int64

# %%
import seaborn as sns

# %%
pd.DataFrame(data_subset['spc_latin'].value_counts()).plot(kind='bar',figsize=(20,10));

# %%
data_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
data_subset['steward']
# Out:
# 0         None
# 1         None
# 2         1or2
# 3         None
# 4         None
#           ...
# 683783    None
# 683784    1or2
# 683785    None
# 683786    None
# 683787    None
# Name: steward, Length: 683788, dtype: object

# %%
stumps=data_subset[data_subset['status']=='Stump'].head(50)
stumps
# Out:
#       tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37     211205         0          16          OnCurb  Stump    NaN       NaN
# 239    203597         0          15          OnCurb  Stump    NaN       NaN
# 641    179766         0          30          OnCurb  Stump    NaN       NaN
# 644    180619         0          10          OnCurb  Stump    NaN       NaN
# 646    208828         0          15          OnCurb  Stump    NaN       NaN
# 648    181973         0          25          OnCurb  Stump    NaN       NaN
# 739    200522         0          17          OnCurb  Stump    NaN       NaN
# 741    174299         0          15          OnCurb  Stump    NaN       NaN
# 743    198633         0          16          OnCurb  Stump    NaN       NaN
# 774    209649         0           5          OnCurb  Stump    NaN       NaN
# 918    208396         0          15          OnCurb  Stump    NaN       NaN
# ...

# %%
data_subset.columns
# Out:
# Index(['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health',
#        'spc_latin', 'spc_common', 'steward', 'guards', 'sidewalk', 'problems',
#        'root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light',
#        'trnk_other', 'brch_light', 'brch_shoe', 'brch_other'],
#       dtype='object')

# %%
tree_health =   data_subset[['root_stone', 'root_grate', 'root_other', 'trunk_wire', 'trnk_light',
       'trnk_other', 'brch_light', 'brch_shoe', 'brch_other']]

# %%
tree_health
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
tree_health.apply(pd.Series.value_counts)
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355
